# %%
import numpy as np
import matplotlib.pyplot as plt

# print options
np.set_printoptions(precision=3)

from chroma import *

# %%
# create a synthetic function

def normalize_sequence(x):
    length = np.linalg.norm(x, axis=0)
    return x / length

def create_sequences():
    L = 100
    w = np.linspace(0, np.pi/2, L)
    ref = np.stack((np.sin(w), np.cos(w))) + 0.10 * np.random.random((2,L))
    ref = normalize_sequence(ref)

    L = 50
    w = np.linspace(0, np.pi/2, L)
    
    # this will make a non-linear matching path
    #     w = np.pi/2 * np.sin(w)
    live = np.stack((np.sin(w), np.cos(w)))  + 0.10 * np.random.random((2,L))
    live = normalize_sequence(live)
    return ref, live

# %%
def dtw(seq_a, seq_b):
    # matrix dimensions
    M = seq_a.shape[1]
    N = seq_b.shape[1]

    # create the cost matrix:
    cost = 1 - np.dot(seq_a.T, seq_b)
    
    # accumulated cost matrix:
    acc_cost = np.zeros((M,N))

    # backtracking matrix:
    back = np.empty((M,N), dtype=np.int)

    # initalize accumulated cost matrix:
    acc_cost[0,0] = cost[0,0]
    back[0,0] = 2
    
    for i in range(1,M):
        acc_cost[i,0] = cost[i,0] + acc_cost[i-1, 0]
        back[i,0] = 1
    for j in range(1,N):
        acc_cost[0,j] = cost[0,j] + acc_cost[0, j-1]
        back[0,j] = 0
    
    STEPS = [(0, -1), (-1, 0), (-1, -1)]
    # DTW algorithm
    for i in range(1,M):
        for j in range(1,N):
            # check 3 steps ending up at i,j:
            options = (acc_cost[i  ,j-1] + cost[i,j],
                       acc_cost[i-1,j]   + cost[i,j],
                       acc_cost[i-1,j-1] + 2*cost[i,j])
            best_step = np.argmin(options)
            acc_cost[i,j] = options[best_step]
            back[i,j] = best_step
    
    # backtrack for path compuation:
    i = M - 1
    j = N - 1
    path = [(i,j)]
    while i > 0 or j > 0:
        step = STEPS[ back[i,j] ]
        i += step[0]
        j += step[1]
        path.append( (i,j) )
    path.reverse()
    path = np.array(path)
    return cost, acc_cost, path

# %%
ref_seq, live_seq = create_sequences()
dtw_cost, dtw_acc_cost, dtw_path = dtw(live_seq, ref_seq)

# %%
plt.imshow(dtw_acc_cost)
plt.plot(dtw_path[:,1], dtw_path[:,0], 'r')
plt.show()

# %%
dtw_acc_cost[0:5, 0:5]
# Out:
# array([[ 0.   ,  0.   ,  0.004,  0.007,  0.015],
#        [ 0.001,  0.002,  0.001,  0.001,  0.003],
#        [ 0.002,  0.004,  0.001,  0.001,  0.002],
#        [ 0.007,  0.012,  0.002,  0.002,  0.001],
#        [ 0.018,  0.028,  0.007,  0.007,  0.003]])

# %%
print dtw_path
# Out:
# [[ 0  0]
#  [ 0  1]
#  [ 1  2]
#  [ 2  2]
#  [ 2  3]
#  [ 3  4]
#  [ 3  5]
#  [ 3  6]
#  [ 3  7]
#  [ 4  8]
#  [ 4  9]
#  [ 5 10]
#  [ 5 11]
#  [ 5 12]
#  [ 5 13]
#  [ 5 14]
#  [ 6 15]
#  [ 6 16]
#  [ 7 16]
#  [ 8 16]
#  [ 9 16]
#  [10 17]
#  [10 18]
#  [10 19]
#  [10 20]
#  [10 21]
#  [11 22]
#  [11 23]
#  [12 24]
#  [12 25]
#  [12 26]
#  [12 27]
#  [13 28]
#  [14 29]
#  [14 30]
#  [15 31]
#  [15 32]
#  [15 33]
#  [15 34]
#  [16 34]
#  [17 34]
#  [18 35]
#  [19 35]
#  [19 36]
#  [19 37]
#  [19 38]
#  [19 39]
#  [20 40]
#  [21 41]
#  [21 42]
#  [22 43]
#  [22 44]
#  [22 45]
#  [22 46]
#  [22 47]
#  [22 48]
#  [23 49]
#  [23 50]
#  [24 51]
#  [24 52]
#  [24 53]
#  [25 54]
#  [26 55]
#  [27 56]
#  [27 57]
#  [28 57]
#  [29 58]
#  [29 59]
#  [30 59]
#  [31 59]
#  [31 60]
#  [31 61]
#  [31 62]
#  [31 63]
#  [31 64]
#  [32 65]
#  [32 66]
#  [32 67]
#  [32 68]
#  [33 69]
#  [33 70]
#  [34 71]
#  [35 72]
#  [35 73]
#  [35 74]
#  [36 75]
#  [37 76]
#  [38 77]
#  [38 78]
#  [38 79]
#  [38 80]
#  [39 81]
#  [39 82]
#  [39 83]
#  [40 83]
#  [41 84]
#  [42 84]
#  [43 84]
#  [43 85]
#  [43 86]
#  [43 87]
#  [44 88]
#  [44 89]
#  [45 89]
#  [45 90]
#  [45 91]
#  [45 92]
#  [46 93]
#  [46 94]
#  [47 94]
#  [47 95]
#  [47 96]
#  [47 97]
#  [48 98]
#  [49 98]
#  [49 99]]

# %%
# Implementation of Online Time Warping Based on Dixon 2005
# This follows the algorithm in the paper very closely, but also fixes some bugs
class OnlineTimeWarping(object):
    def __init__(self, ref, params):
        super(OnlineTimeWarping, self).__init__()

        self.c = params['c']
        self.max_run_count = params['max_run_count']

        F = ref.shape[0]     # number of features
        N = ref.shape[1]     # length of ref sequence
        M = 2 * ref.shape[1] # length of live sequence (2x for now)

        # refernce sequence
        self.ref = ref 
        
        # live sequence:
        self.live = -1 * np.ones((F, M))
        
        # cost matrix
        self.cost = -1 * np.ones((M,N))
        
        # acc cost matrix. Initialize with large values to handle
        # non-computed edges
        self.acc_cost = 10**10 * np.ones((M,N))
                
        # algorithm state vars
        self.t = 0 # index into live
        self.j = 0  # index into ref
        self.previous = None
        self.run_count = 1
        self.direction = "Both"
        self.path = []
        self.first_insert = True
        
    def insert(self, live_sample):
        print '\n\nInsert: cur index', self.t, self.j

        if self.first_insert:
            self.first_insert = False
            self.live[:,self.t] = live_sample
            self.eval_path_cost(self.t, self.j)
            return
        
        # Process a Row ('Row' or 'Both')
        assert(self.direction == 'Row' or self.direction == 'Both')
        self.t += 1
        
        # check end condition
        if self.t >= self.live.shape[1]:
            print 'Done. Ran out of room in pre-allocated live-sequence'
            return
        self.live[:,self.t] = live_sample
        
        k1 = max(0, self.j - self.c + 1)
        k2 = self.j + 1
        print 'row[{} : {},{}]'.format(self.t, k1, k2)
        for k in range(k1, k2):
            self.eval_path_cost(self.t, k)

        while True:
            # Process a Column ('Column' or 'Both')
            if self.direction != 'Row':
                self.j += 1
                # check end conditions
                if self.j >= self.ref.shape[1]:
                    print 'Done. Ran out of ref-sequence'
                    return
                
                k1 = max(0, self.t - self.c + 1)
                k2 = self.t + 1
                print 'col[{},{} : {}]'.format(k1, k2, self.j)
                for k in range(k1, k2):
                    self.eval_path_cost(k, self.j)            

            # Unlike paper, only call set_direction once for each loop.
            self.set_direction()
            print self.direction
            
            # if we need to process a row next, we break and wait for next input
            if self.direction != 'Column':
                break
                
    
    # this function sets the entire "live" data at once, which is not how
    # it will run in real-time, but more closely matches the algorithm in the
    # paper.
    def set_live(self, live):
        self.t = 0
        self.j = 0
        self.previous = None
        self.direction = "Both"
        self.run_count = 1
        self.path = []
        
        self.fill_input(live)
        self.eval_path_cost(self.t, self.j)
        
        while True:
            print '\n\ncur index', self.t, self.j
            
            # Unlike paper, only call set_direction once at the start of each loop.
            self.set_direction()
            print self.direction
            
            # Process a Row ('Row' or 'Both')
            if self.direction != 'Column':
                self.t += 1
                # check end conditions
                if self.t >= live.shape[1]:
                    print 'Done. Ran out of live sequence'
                    break
                if self.t >= self.live.shape[1]:
                    print 'Done. Ran out of room in pre-allocated live-sequence'
                    break

                self.fill_input(live)
                k1 = max(0, self.j - self.c + 1)
                k2 = self.j + 1
                print 'row[{} : {},{}]'.format(self.t, k1, k2)
                for k in range(k1, k2):
                    self.eval_path_cost(self.t, k)
                
            # Process a Column ('Column' or 'Both')
            if self.direction != 'Row':
                self.j += 1
                # check end conditions
                if self.j >= self.ref.shape[1]:
                    print 'Done. Ran out of ref-sequence'
                    break
                
                k1 = max(0, self.t - self.c + 1)
                k2 = self.t + 1
                print 'col[{},{} : {}]'.format(k1, k2, self.j)
                for k in range(k1, k2):
                    self.eval_path_cost(k, self.j)
                
        # turn path into np.array at end.
        self.path = np.array(self.path)
    
    
    # this is INPUT(t). It fills in one additional step from the live input
    # into the current pointer, self.t
    def fill_input(self, live):
        self.live[:,self.t] = live[:,self.t] 
    
    # This does two things: calculates if next update show be 
    # row, column, or both. And finds the current optimal point and adds it to the
    # path.
    def set_direction(self):
        print '  Set Direction at ({},{})'.format(self.t, self.j)

        # moved this calculation to happen all the time, so that we can
        # have a path right from the start:
        x,y = self.best_point()
        print '    best_point: ({},{})'.format(x,y)
        self.path.append((x,y))

        # startup condition when we always alternate row/column
        if self.t < self.c:
            self.direction = 'Both'
        
        # slope enforcement: keep search space to within
        # a max runcount.
        elif self.run_count >= self.max_run_count:
            print 'exceeded run count'
            self.direction = 'Column' if self.previous == 'Row' else 'Row'
        
        # choose row or column based on location of current optimal point
        elif x < self.t:
            self.direction = 'Column'
        elif y < self.j:
            self.direction = 'Row'
        else:
            self.direction = 'Both'
    
        # update run_count - the number of time we see
        # consecutive rows or consecutive coluns.
        if self.direction == self.previous:
            self.run_count += 1
        else:
            self.run_count = 1
        print 'run-count', self.run_count
        if self.direction != 'Both':
            self.previous = self.direction
    
    
    # find minimum cost of current point (self.t, self.j)'s row and column
    def best_point(self):    
        # check row
        j1 = max(0, self.j - self.c + 1)
        j2 = self.j + 1
        print '    row min [{}, {}:{}]'.format(self.t, j1, j2)
        best_j = j1 + np.argmin( self.acc_cost[self.t, j1:j2] )
        cost_j = self.acc_cost[self.t, best_j]
        
        # check column
        t1 = max(0, self.t - self.c + 1)
        t2 = self.t + 1
        print '    col min [{}:{}, {}]'.format(t1, t2, self.j)
        best_t = t1 + np.argmin( self.acc_cost[t1:t2, self.j] )
        cost_t = self.acc_cost[best_t, self.j]
    
        # choose best cell from row or column:
        if cost_j < cost_t:
            return (self.t, best_j)
        else:
            return (best_t, self.j)
    
    
    # eval cost at location (x,y)
    def eval_path_cost(self, x, y):
        print '  eval({},{})'.format(x,y)
        assert(self.live[0,x] != -1)
        
        # calculate cost at this cell:
        self.cost[x,y] = 1 - np.dot(self.live[:,x], self.ref[:,y])
        
        # initial condition for accumulated cost at (0,0)
        if x == 0 and y == 0:
            self.acc_cost[x,y] = self.cost[x,y]
            return
        
        # run one DTW step for updating accumulated cost at this cell
        steps = []
        if y > 0:
            steps.append( self.acc_cost[x,   y-1] + self.cost[x,y] )
        if x > 0:
            steps.append( self.acc_cost[x-1, y  ] + self.cost[x,y] )
        if x > 0 and y > 0:
            steps.append( self.acc_cost[x-1, y-1] + 2 * self.cost[x,y] )
                 
        best_cost = min(steps)
        print '    ', steps
        print '    ', best_cost
        self.acc_cost[x,y] = best_cost

# %%
params = { 'c': 5, 'max_run_count': 3}
otw = OnlineTimeWarping(ref_seq, params)

# otw.set_live(live_seq)

for i in range(live_seq.shape[1]):
    otw.insert( live_seq[:,i] )
# Out:
# Insert: cur index 0 0
#   eval(0,0)
#
#
# Insert: cur index 0 0
# row[1 : 0,1]
#   eval(1,0)
#      [0.00087628169295306257]
#      0.000876281692953
# col[0,2 : 1]
#   eval(0,1)
#      [0.00049669363084825502]
#      0.000496693630848
#   eval(1,1)
#      [0.0024470901915228938, 0.0020675021294180862, 0.0036337016799193878]
#      0.00206750212942
#   Set Direction at (1,1)
#     row min [1, 0:2]
#     col min [0:2, 1]
#     best_point: (0,1)
# run-count 1
# Both
#
#
# Insert: cur index 1 1
# row[2 : 0,2]
#   eval(2,0)
#      [0.001684671474428634]
#      0.00168467147443
#   eval(2,1)
#      [0.004033204653127509, 0.0044160353081169612, 0.0055733480503508126]
#      0.00403320465313
# col[0,3 : 2]
#   eval(0,2)
#      [0.0038498556474446666]
#      0.00384985564744
#   eval(1,2)
#      [0.0023279008086265485, 0.0041102543266531288, 0.0010174909892651796]
#      0.00101749098927
#   eval(2,2)
#      [0.004086562576267605, 0.0010708489124052756, 0.0021742179756982782]
#      0.00107084891241
#   Set Direction at (2,2)
#     row min [2, 0:3]
#     col min [0:3, 2]
#     best_point: (1,2)
# run-count 1
# Both
#
#
# Insert: cur index 2 2
# row[3 : 0,3]
#   eval(3,0)
#      [0.0066989197132515388]
#      0.00669891971325
#   eval(3,1)
#      [0.014946373146220382, 0.012280658086096352, 0.01817957834036632]
#      0.0122806580861
#   eval(3,2)
#      [0.013512568374017375, 0.0023027592003262987, 0.0064970252289695551]
#      0.00230275920033
# col[0,4 : 3]
#   eval(0,3)
#      [0.007407967986121311]
#      0.00740796798612
#   eval(1,3)
#      [0.0013372453235868109, 0.0077277223204429424, 0.0044893643160879293]
#      0.00133724532359
#   eval(2,3)
#      [0.0011527432765012779, 0.0014191396876828133, 0.0011812797174571843]
#      0.0011527432765
#   eval(3,3)
#      [0.0034152593094538553, 0.0022652433856288345, 0.0032958491306603888]
#      0.00226524338563
#   Set Direction at (3,3)
#     row min [3, 0:4]
#     col min [0:4, 3]
#     best_point: (2,3)
# run-count 1
# Both
#
#
# Insert: cur index 3 3
# row[4 : 0,4]
#   eval(4,0)
#      [0.017755360940654108]
#      0.0177553609407
#   eval(4,1)
#      [0.033410368979473137, 0.027935666124915381, 0.038008935790889598]
#      0.0279356661249
#   eval(4,2)
#      [0.032763131030490111, 0.0071302241059010285, 0.021935587897245812]
#      0.0071302241059
#   eval(4,3)
#      [0.01171853695281988, 0.0068535562325476862, 0.011479384894164002]
#      0.00685355623255
# col[0,5 : 4]
#   eval(0,4)
#      [0.014628075157457676]
#      0.0146280751575
#   eval(1,4)
#      [0.003206097539118935, 0.0164969273729898, 0.011145672417185559]
#      0.00320609753912
#   eval(2,4)
#      [0.0023361738049085812, 0.0043895280675262383, 0.0037041063804014174]
#      0.00233617380491
#   eval(3,4)
#      [0.0023292818828190009, 0.0024002123020987476, 0.0012808202708816108]
#      0.00128082027088
#   eval(4,4)
#      [0.0086514732039494335, 0.0030787372422833581, 0.0058610773284323292]
#      0.00307873724228
#   Set Direction at (4,4)
#     row min [4, 0:5]
#     col min [0:5, 4]
#     best_point: (3,4)
# run-count 1
# Both
#
#
# Insert: cur index 4 4
# row[5 : 0,5]
#   eval(5,0)
#      [0.032685629563779739]
#      0.0326856295638
#   eval(5,1)
#      [0.05288902863480438, 0.048139065195940023, 0.058162159082703391]
#      0.0481390651959
#   eval(5,2)
#      [0.055629812816389568, 0.014620971726350573, 0.042917161365814471]
#      0.0146209717264
#   eval(5,3)
#      [0.021813263701008112, 0.014045848207205225, 0.021514808055216106]
#      0.0140458482072
#   eval(5,4)
#      [0.017584424355730599, 0.0066173133908087323, 0.013930708529598435]
#      0.00661731339081
# col[1,6 : 5]
#   eval(1,5)
#      [0.0054692006402708992, 10000000000.002264, 0.019154281359761605]
#      0.00546920064027
#   eval(2,5)
#      [0.0038372458659123865, 0.0069702727012747046, 0.0062082416611265456]
#      0.00383724586591
#   eval(3,5)
#      [0.0012942037491798786, 0.0038506293442106543, 0.0023629407615051168]
#      0.00129420374918
#   eval(4,5)
#      [0.0045272635560016372, 0.0027427300628981577, 0.004177872898318169]
#      0.0027427300629
#   eval(5,5)
#      [0.0096583288123093247, 0.0057837454843987501, 0.009160768085284543]
#      0.0057837454844
#   Set Direction at (5,5)
#     row min [5, 1:6]
#     col min [1:6, 5]
#     best_point: (3,5)
# run-count 1
# Column
# col[1,6 : 6]
#   eval(1,6)
#      [0.0076914179947403793, 10000000000.002222, 10000000000.004444]
#      0.00769141799474
#   eval(2,6)
#      [0.0053050480503694653, 0.0091592201791974581, 0.0084048050091850568]
#      0.00530504805037
#   eval(3,6)
#      [0.0013109340335223374, 0.0053217783347119241, 0.0038707064345973041]
#      0.00131093403352
#   eval(4,6)
#      [0.004224308462660975, 0.0027925124332851547, 0.0042573605487055133]
#      0.00279251243329
#   eval(5,6)
#      [0.0088725480197904272, 0.0058813149686768318, 0.0089203351336815118]
#      0.00588131496868
#   Set Direction at (5,6)
#     row min [5, 2:7]
#     col min [1:6, 6]
#     best_point: (3,6)
# run-count 2
# Column
# col[1,6 : 7]
#   eval(1,7)
#      [0.0086110252781912422, 10000000000.000919, 10000000000.001839]
#      0.00861102527819
#   eval(2,7)
#      [0.0057670393970311595, 0.0090730166248529365, 0.0086154006880637679]
#      0.00576703939703
#   eval(3,7)
#      [0.0017482162248213529, 0.006204321588330175, 0.0061796124329674962]
#      0.00174821622482
#   eval(4,7)
#      [0.0058510125897799359, 0.004806716381316134, 0.0074279343465118997]
#      0.00480671638132
#   eval(5,7)
#      [0.011120390197745023, 0.010045791610384325, 0.013270662891421536]
#      0.0100457916104
#   Set Direction at (5,7)
#     row min [5, 3:8]
#     col min [1:6, 7]
#     best_point: (3,7)
# run-count 3
# Column
# col[1,6 : 8]
#   eval(1,8)
#      [0.013497166289382134, 10000000000.004887, 10000000000.009771]
#      0.0134971662894
#   eval(2,8)
#      [0.0094975476568992523, 0.017227674549250227, 0.016072041797927428]
#      0.0094975476569
#   eval(3,8)
#      [0.0020975128624218797, 0.0098468442944997792, 0.0064656326722322133]
#      0.00209751286242
#   eval(4,8)
#      [0.0050536905324349846, 0.0023444870135407303, 0.002242164527059054]
#      0.00224216452706
#   eval(5,8)
#      [0.011122161219209947, 0.0033185341358846765, 0.006959455598967379]
#      0.00331853413588
#   Set Direction at (5,8)
#     row min [5, 4:9]
#     col min [1:6, 8]
#     best_point: (3,8)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 5 8
# row[6 : 4,9]
#   eval(6,4)
#      [10000000000.007944, 0.014561765952688099, 0.029934753330963959]
#      0.0145617659527
#   eval(6,5)
#      [0.021752090372728294, 0.012974069904438945, 0.020997962230889122]
#      0.0129740699044
#   eval(6,6)
#      [0.020237698578827845, 0.013144943643065732, 0.02031100283317655]
#      0.0131449436431
#   eval(6,7)
#      [0.023551332142239367, 0.02045218010955796, 0.026694091967024103]
#      0.0204521801096
#   eval(6,8)
#      [0.024355675547793276, 0.0072220295741199925, 0.017852782486854957]
#      0.00722202957412
#   Set Direction at (6,8)
#     row min [6, 4:9]
#     col min [2:7, 8]
#     best_point: (3,8)
# run-count 1
# Column
# col[2,7 : 9]
#   eval(2,9)
#      [0.012641441457809766, 10000000000.003143, 0.019784953891203161]
#      0.0126414414578
#   eval(3,9)
#      [0.0022846020820871393, 0.012828530677475025, 0.0098717260962297715]
#      0.00228460208209
#   eval(4,9)
#      [0.002671762552723389, 0.0027142001077514744, 0.0029567089137505498]
#      0.00267176255272
#   eval(5,9)
#      [0.0047487550003775247, 0.0041019834172162373, 0.0051026062560447505]
#      0.00410198341722
#   eval(6,9)
#      [0.011776176189700727, 0.0086561300327969715, 0.012426827367046145]
#      0.0086561300328
#   Set Direction at (6,9)
#     row min [6, 5:10]
#     col min [2:7, 9]
#     best_point: (3,9)
# run-count 2
# Column
# col[2,7 : 10]
#   eval(2,10)
#      [0.022999507281336706, 10000000000.010359, 10000000000.020716]
#      0.0229995072813
#   eval(3,10)
#      [0.005817508553100148, 0.026532413752349715, 0.019707254399835783]
#      0.0058175085531
#   eval(4,10)
#      [0.0032992000602996008, 0.0064449460606763598, 0.0035394770972395628]
#      0.0032992000603
#   eval(5,10)
#      [0.0041652605031213819, 0.0033624771462047454, 0.0027983167245336782]
#      0.00279831672453
#   eval(6,10)
#      [0.0091283967457809201, 0.0032705834375176268, 0.0050465168431841345]
#      0.00327058343752
#   Set Direction at (6,10)
#     row min [6, 6:11]
#     col min [2:7, 10]
#     best_point: (5,10)
# run-count 3
# Column
# col[2,7 : 11]
#   eval(2,11)
#      [0.030373895818967767, 10000000000.007374, 10000000000.01475]
#      0.030373895819
#   eval(3,11)
#      [0.0077109231934704425, 0.032267310459338061, 0.026786336562077295]
#      0.00771092319347
#   eval(4,11)
#      [0.0033822729323061962, 0.0077939960654770379, 0.0059836542971133388]
#      0.00338227293231
#   eval(5,11)
#      [0.0028620089925290859, 0.0034459652003016039, 0.0034265845962904162]
#      0.00286200899253
#   eval(6,11)
#      [0.0046891315137976841, 0.0042805570688091432, 0.0056354128770937928]
#      0.00428055706881
#   Set Direction at (6,11)
#     row min [6, 7:12]
#     col min [2:7, 11]
#     best_point: (5,11)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 6 11
# row[7 : 7,12]
#   eval(7,7)
#      [10000000000.007729, 0.028180528302580998, 0.028601640029111808]
#      0.0281805283026
#   eval(7,8)
#      [0.030518853638605181, 0.0095603549101441754, 0.025128830781606326]
#      0.00956035491014
#   eval(7,9)
#      [0.012408150695506825, 0.011503925818159622, 0.012917621144845293]
#      0.0115039258182
#   eval(7,10)
#      [0.011561683955487512, 0.003328341574845517, 0.0087716463074527518]
#      0.00332834157485
#   eval(7,11)
#      [0.0038822069739348208, 0.0048344224678984471, 0.0043783142356962346]
#      0.00388220697393
#   Set Direction at (7,11)
#     row min [7, 7:12]
#     col min [3:8, 11]
#     best_point: (5,11)
# run-count 1
# Column
# col[3,8 : 12]
#   eval(3,12)
#      [0.0089395985504098219, 10000000000.001228, 0.032831246532846525]
#      0.00893959855041
#   eval(4,12)
#      [0.0033826958193342582, 0.0089400214374378839, 0.0077117689675265666]
#      0.00338269581933
#   eval(5,12)
#      [0.0031324342835500341, 0.0036531211103552064, 0.0039231235143480925]
#      0.00313243428355
#   eval(6,12)
#      [0.0064079885226641098, 0.0052598657374050006, 0.0071168719002390191]
#      0.00525986573741
#   eval(7,12)
#      [0.00490600848560796, 0.0062836672490781398, 0.0063281600921554215]
#      0.00490600848561
#   Set Direction at (7,12)
#     row min [7, 8:13]
#     col min [3:8, 12]
#     best_point: (5,12)
# run-count 2
# Column
# col[3,8 : 13]
#   eval(3,13)
#      [0.012274353887510858, 10000000000.003334, 10000000000.00667]
#      0.0122743538875
#   eval(4,13)
#      [0.0039282256624749712, 0.012819883730651571, 0.010030658236691248]
#      0.00392822566247
#   eval(5,13)
#      [0.0031716511941592973, 0.0039674425730842344, 0.0034611296405527847]
#      0.00317165119416
#   eval(6,13)
#      [0.005808542623310986, 0.0037203280800652827, 0.0042297880553620049]
#      0.00372032808007
#   eval(7,13)
#      [0.0049923537924414507, 0.0038066733868987734, 0.0054325563510719821]
#      0.0038066733869
#   Set Direction at (7,13)
#     row min [7, 9:14]
#     col min [3:8, 13]
#     best_point: (5,13)
# run-count 3
# Column
# col[3,8 : 14]
#   eval(3,14)
#      [0.014815019279249997, 10000000000.002541, 10000000000.005081]
#      0.0148150192792
#   eval(4,14)
#      [0.004184532680677755, 0.015071326297452781, 0.012786967923916426]
#      0.00418453268068
#   eval(5,14)
#      [0.0031728291735435565, 0.0041857106600620142, 0.0039305816212434896]
#      0.00317282917354
#   eval(6,14)
#      [0.0046671335707699768, 0.0041196346642482506, 0.0050652621755686855]
#      0.00411963466425
#   eval(7,14)
#      [0.0040835499838384193, 0.0043965112611878965, 0.0042740812739445744]
#      0.00408354998384
#   Set Direction at (7,14)
#     row min [7, 10:15]
#     col min [3:8, 14]
#     best_point: (5,14)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 7 14
# row[8 : 10,15]
#   eval(8,10)
#      [10000000000.000267, 0.0035952337712558124, 0.012037710210980213]
#      0.00359523377126
#   eval(8,11)
#      [0.0046365812090857217, 0.0049235544117647301, 0.0054110364505053354]
#      0.00463658120909
#   eval(8,12)
#      [0.0062956184240282598, 0.0065650457005504981, 0.007200281403819897]
#      0.00629561842403
#   eval(8,13)
#      [0.0066206661825932711, 0.0041317211454637848, 0.0055561040027379827]
#      0.00413172114546
#   eval(8,14)
#      [0.0047756582698527117, 0.0047274871082273462, 0.0050945476356766273]
#      0.00472748710823
#   Set Direction at (8,14)
#     row min [8, 10:15]
#     col min [4:9, 14]
#     best_point: (5,14)
# run-count 1
# Column
# col[4,9 : 15]
#   eval(4,15)
#      [0.0094456095240904592, 10000000000.00526, 0.025337172966075405]
#      0.00944560952409
#   eval(5,15)
#      [0.0062481545139220218, 0.012520934864468924, 0.010335183361434686]
#      0.00624815451392
#   eval(6,15)
#      [0.0047843010394124086, 0.0069128208890861798, 0.0045021619238718724]
#      0.00450216192387
#   eval(7,15)
#      [0.0056763495424234645, 0.0060949614824569176, 0.007305233781418341]
#      0.00567634954242
#   eval(8,15)
#      [0.0056993915416325702, 0.0066482539758286885, 0.0060273588506488673]
#      0.00569939154163
#   Set Direction at (8,15)
#     row min [8, 11:16]
#     col min [4:9, 15]
#     best_point: (8,13)
# run-count 1
# Row
#
#
# Insert: cur index 8 15
# row[9 : 11,16]
#   eval(9,11)
#      [10000000000.002279, 0.0069160848957174892, 0.0081542411445193475]
#      0.00691608489572
#   eval(9,12)
#      [0.010074818844967415, 0.0094543523732781853, 0.010954049107585573]
#      0.00945435237328
#   eval(9,13)
#      [0.01057706736846864, 0.0052544361406542395, 0.0085410484144091692]
#      0.00525443614065
#   eval(9,14)
#      [0.006923330247739945, 0.0063963812153130517, 0.0074695093596351958]
#      0.00639638121531
#   eval(9,15)
#      [0.0066427795089077923, 0.0059457898352273109, 0.0052202836954168275]
#      0.00522028369542
#   Set Direction at (9,15)
#     row min [9, 11:16]
#     col min [5:10, 15]
#     best_point: (6,15)
# run-count 1
# Column
# col[5,10 : 16]
#   eval(5,16)
#      [0.007436607930356498, 10000000000.001188, 0.011822516356959412]
#      0.00743660793036
#   eval(6,16)
#      [0.0045251067280283053, 0.0074595527345129309, 0.0062940441222348875]
#      0.00452510672803
#   eval(7,16)
#      [0.0060343975942077632, 0.004883154779812604, 0.00521825802744047]
#      0.00488315477981
#   eval(8,16)
#      [0.0058031328833512141, 0.0049868961215312479, 0.0058838322258607523]
#      0.00498689612153
#   eval(9,16)
#      [0.0052483213144504104, 0.0050149337405648309, 0.0057554667796997361]
#      0.00501493374056
#   Set Direction at (9,16)
#     row min [9, 12:17]
#     col min [5:10, 16]
#     best_point: (6,16)
# run-count 2
# Column
# col[5,10 : 17]
#   eval(5,17)
#      [0.012251478875607735, 10000000000.004814, 10000000000.00963]
#      0.0122514788756
#   eval(6,17)
#      [0.0061031531168458386, 0.013829525264425269, 0.010592700707991565]
#      0.00610315311685
#   eval(7,17)
#      [0.0077829208892352675, 0.0090029192262685021, 0.010324638946873632]
#      0.00778292088924
#   eval(8,17)
#      [0.0070224899493460669, 0.0098185147170500864, 0.0089543424354422418]
#      0.00702248994935
#   eval(9,17)
#      [0.0058936136652885107, 0.0079011698740697467, 0.0067442559709786076]
#      0.00589361366529
#   Set Direction at (9,17)
#     row min [9, 13:18]
#     col min [5:10, 17]
#     best_point: (9,16)
# run-count 1
# Row
#
#
# Insert: cur index 9 17
# row[10 : 13,18]
#   eval(10,13)
#      [10000000000.006279, 0.011533454040185132, 0.022012388172339969]
#      0.0115334540402
#   eval(10,14)
#      [0.019028739626688496, 0.013891666801816416, 0.020245007313660968]
#      0.0138916668018
#   eval(10,15)
#      [0.014795993921360551, 0.0061246108149609624, 0.0082050354544013215]
#      0.00612461081496
#   eval(10,16)
#      [0.0087312924405568149, 0.0076216153661606834, 0.010433646946608532]
#      0.00762161536616
#   eval(10,17)
#      [0.0078816840176704206, 0.006153682316798248, 0.0055350710435843054]
#      0.00553507104358
#   Set Direction at (10,17)
#     row min [10, 13:18]
#     col min [6:11, 17]
#     best_point: (10,17)
# run-count 1
# Both
#
#
# Insert: cur index 10 17
# row[11 : 13,18]
#   eval(11,13)
#      [10000000000.011297, 0.022831626620509859, 10000000000.022596]
#      0.0228316266205
#   eval(11,14)
#      [0.035740749308728614, 0.026800789490035171, 0.037351699416622641]
#      0.02680078949
#   eval(11,15)
#      [0.030069213752475732, 0.0093930350774015237, 0.020428515326697538]
#      0.0093930350774
#   eval(11,16)
#      [0.015498640811297149, 0.013727221100056308, 0.018335822282752212]
#      0.0137272211001
#   eval(11,17)
#      [0.015596198898645497, 0.007404048842173494, 0.011359570963339061]
#      0.00740404884217
# col[7,12 : 18]
#   eval(7,18)
#      [0.014535624600079844, 10000000000.006752, 0.019608560538534991]
#      0.0145356246001
#   eval(8,18)
#      [0.012417510126466524, 0.019930644777200301, 0.018572961243476183]
#      0.0124175101265
#   eval(9,18)
#      [0.0092561170741930487, 0.015780013535371062, 0.013747496767155143]
#      0.00925611707419
#   eval(10,18)
#      [0.005684680754368121, 0.0094057267849768644, 0.0061928330868561421]
#      0.00568468075437
#   eval(11,18)
#      [0.0076254479576788325, 0.0059060798698734596, 0.0059778692745949824]
#      0.00590607986987
#   Set Direction at (11,18)
#     row min [11, 14:19]
#     col min [7:12, 18]
#     best_point: (10,18)
# run-count 1
# Column
# col[7,12 : 19]
#   eval(7,19)
#      [0.015944682401890287, 10000000000.00141, 10000000000.002819]
#      0.0159446824019
#   eval(8,19)
#      [0.013247097089315818, 0.01677426936473958, 0.016194798525778431]
#      0.0132470970893
#   eval(9,19)
#      [0.0094336417832791009, 0.01342462179840187, 0.012772559544638629]
#      0.00943364178328
#   eval(10,19)
#      [0.0067373468760677513, 0.010486307904978731, 0.011361449317592309]
#      0.00673734687607
#   eval(11,19)
#      [0.0094512673686133475, 0.010282534374807639, 0.012775055751847897]
#      0.00945126736861
#   Set Direction at (11,19)
#     row min [11, 15:20]
#     col min [7:12, 19]
#     best_point: (11,18)
# run-count 1
# Row
#
#
# Insert: cur index 11 19
# row[12 : 15,20]
#   eval(12,15)
#      [10000000000.004404, 0.013797552993666584, 0.035609825322565292]
#      0.0137975529937
#   eval(12,16)
#      [0.021423698051768802, 0.021353366158158527, 0.02464532519360596]
#      0.0213533661582
#   eval(12,17)
#      [0.024102438996691844, 0.010153121680706811, 0.019225366777122943]
#      0.0101531216807
#   eval(12,18)
#      [0.01073315135383679, 0.0064861095430034377, 0.0085641081884334502]
#      0.006486109543
#   eval(12,19)
#      [0.01121091182576972, 0.01417606965137963, 0.015355684435406025]
#      0.0112109118258
#   Set Direction at (12,19)
#     row min [12, 15:20]
#     col min [8:13, 19]
#     best_point: (12,18)
# run-count 2
# Row
#
#
# Insert: cur index 12 19
# row[13 : 15,20]
#   eval(13,15)
#      [10000000000.010839, 0.024636172026739955, 10000000000.021677]
#      0.0246361720267
#   eval(13,16)
#      [0.040269163175704503, 0.036986357307123074, 0.04506353529159568]
#      0.0369863573071
#   eval(13,17)
#      [0.045121385220309507, 0.018288149593893244, 0.037623421984531391]
#      0.0182881495939
#   eval(13,18)
#      [0.022116941841981763, 0.010314901791091957, 0.01781070617688385]
#      0.0103149017911
#   eval(13,19)
#      [0.021651926561590429, 0.022547936596268192, 0.029160159084000381]
#      0.0216519265616
#   Set Direction at (13,19)
#     row min [13, 15:20]
#     col min [9:14, 19]
#     best_point: (10,19)
# run-count 1
# Column
# col[9,14 : 20]
#   eval(9,20)
#      [0.0096301732060983802, 10000000000.000196, 0.013640159934954377]
#      0.0096301732061
#   eval(10,20)
#      [0.0077453989928766287, 0.010638225322907258, 0.011449746016896856]
#      0.00774539899288
#   eval(11,20)
#      [0.012914228209856327, 0.011208359834119608, 0.013663268558553709]
#      0.0112083598341
#   eval(12,20)
#      [0.015840741453513996, 0.015838189461863883, 0.018710926624101898]
#      0.0158381894619
#   eval(13,20)
#      [0.032841814499658506, 0.02702807739993196, 0.033590687701905875]
#      0.0270280773999
#   Set Direction at (13,20)
#     row min [13, 16:21]
#     col min [9:14, 20]
#     best_point: (10,20)
# run-count 2
# Column
# col[9,14 : 21]
#   eval(9,21)
#      [0.011174667653164549, 10000000000.001545, 10000000000.00309]
#      0.0111746676532
#   eval(10,21)
#      [0.0077872154074388744, 0.011216484067726795, 0.0097138060352228717]
#      0.00778721540744
#   eval(11,21)
#      [0.012335630204481474, 0.0089144857778007403, 0.0099999397336003604]
#      0.0089144857778
#   eval(12,21)
#      [0.017668034244171515, 0.010744330560108373, 0.014868049398734873]
#      0.0107443305601
#   eval(13,21)
#      [0.033516640453942981, 0.017232893614119393, 0.028815315569885924]
#      0.0172328936141
#   Set Direction at (13,21)
#     row min [13, 17:22]
#     col min [9:14, 21]
#     best_point: (10,21)
# run-count 3
# Column
# col[9,14 : 22]
#   eval(9,22)
#      [0.021432244524120958, 10000000000.010258, 10000000000.020515]
#      0.0214322445241
#   eval(10,22)
#      [0.010876402033966004, 0.024521431150648088, 0.017353040906218808]
#      0.010876402034
#   eval(11,22)
#      [0.0097256774065328511, 0.011687593662698115, 0.009409598664903096]
#      0.0094095986649
#   eval(12,22)
#      [0.011115954344855905, 0.0097812224496506284, 0.0096577333472958049]
#      0.0096577333473
#   eval(13,22)
#      [0.017576378753007327, 0.010001218486183738, 0.01143130083788424]
#      0.0100012184862
#   Set Direction at (13,22)
#     row min [13, 18:23]
#     col min [9:14, 22]
#     best_point: (11,22)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 13 22
# row[14 : 18,23]
#   eval(14,18)
#      [10000000000.006334, 0.016649489696378583, 0.030957325404466496]
#      0.0166494896964
#   eval(14,19)
#      [0.032063083496150058, 0.037065520361361903, 0.041142089390634906]
#      0.0320630834962
#   eval(14,20)
#      [0.047305209446861562, 0.042270203350643465, 0.052136178463013438]
#      0.0422702033506
#   eval(14,21)
#      [0.051923507585972084, 0.026886197849448012, 0.046334685870589198]
#      0.0268861978494
#   eval(14,22)
#      [0.028201356073397132, 0.011316376710132858, 0.019863210062017633]
#      0.0113163767101
#   Set Direction at (14,22)
#     row min [14, 18:23]
#     col min [10:15, 22]
#     best_point: (11,22)
# run-count 1
# Column
# col[10,15 : 23]
#   eval(10,23)
#      [0.010908900452944903, 10000000000.000032, 0.021497241362078756]
#      0.0109089004529
#   eval(11,23)
#      [0.0098679801911762954, 0.011367281979218102, 0.011793165086512403]
#      0.00986798019118
#   eval(12,23)
#      [0.010594918599030834, 0.010805165442911324, 0.011283969168373154]
#      0.010594918599
#   eval(13,23)
#      [0.014679942837190985, 0.01527364295003808, 0.019015182049310297]
#      0.0146799428372
#   eval(14,23)
#      [0.018731275255290392, 0.022094841382348518, 0.024831015576498805]
#      0.0187312752553
#   Set Direction at (14,23)
#     row min [14, 19:24]
#     col min [10:15, 23]
#     best_point: (11,23)
# run-count 2
# Column
# col[10,15 : 24]
#   eval(10,24)
#      [0.012177376954401575, 10000000000.001268, 10000000000.002537]
#      0.0121773769544
#   eval(11,24)
#      [0.0099403658131047568, 0.012249762576330037, 0.011053671696801826]
#      0.0099403658131
#   eval(12,24)
#      [0.010595404663386265, 0.0099408518774601884, 0.0098689523198871587]
#      0.00986895231989
#   eval(13,24)
#      [0.016162535520765964, 0.011351545003462138, 0.013560103966180792]
#      0.0113515450035
#   eval(14,24)
#      [0.02189304164248429, 0.014513311390656036, 0.021003475611578781]
#      0.0145133113907
#   Set Direction at (14,24)
#     row min [14, 20:25]
#     col min [10:15, 24]
#     best_point: (12,24)
# run-count 3
# Column
# col[10,15 : 25]
#   eval(10,25)
#      [0.015963900216607985, 10000000000.003786, 10000000000.007572]
#      0.0159639002166
#   eval(11,25)
#      [0.011126434122831541, 0.017149968526334769, 0.014549513573855144]
#      0.0111264341228
#   eval(12,25)
#      [0.010505818073468065, 0.011763299876412447, 0.011214097320266569]
#      0.0105058180735
#   eval(13,25)
#      [0.011509658559469726, 0.010663931629475654, 0.010185179431902336]
#      0.0101851794319
#   eval(14,25)
#      [0.015431848068151122, 0.011103716109397421, 0.013188618358452309]
#      0.0111037161094
#   Set Direction at (14,25)
#     row min [14, 21:26]
#     col min [10:15, 25]
#     best_point: (13,25)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 14 25
# row[15 : 21,26]
#   eval(15,21)
#      [10000000000.014046, 0.040931382574107222, 0.070360572799961885]
#      0.0409313825741
#   eval(15,22)
#      [0.044132122047371047, 0.014517116183396683, 0.033287676795975663]
#      0.0145171161834
#   eval(15,23)
#      [0.025834587852077151, 0.030048746923970859, 0.033951320047493794]
#      0.0258345878521
#   eval(15,24)
#      [0.031691139025635584, 0.020369862564214469, 0.030444377602407258]
#      0.0203698625642
#   eval(15,25)
#      [0.022932243767108451, 0.013666097312291403, 0.019638073796444]
#      0.0136660973123
#   Set Direction at (15,25)
#     row min [15, 21:26]
#     col min [11:16, 25]
#     best_point: (13,25)
# run-count 1
# Column
# col[11,16 : 26]
#   eval(11,26)
#      [0.011582252857801456, 10000000000.000456, 0.016875537686547815]
#      0.0115822528578
#   eval(12,26)
#      [0.010653327965741588, 0.011729762750074979, 0.011421453907378587]
#      0.0106533279657
#   eval(13,26)
#      [0.010843876914299111, 0.011312025448138363, 0.011823213038261615]
#      0.0108438769143
#   eval(14,26)
#      [0.012986833639313522, 0.012726994444215212, 0.013951414491734537]
#      0.0127269944442
#   eval(15,26)
#      [0.017723946251314571, 0.016784843383238379, 0.019219413987443756]
#      0.0167848433832
#   Set Direction at (15,26)
#     row min [15, 22:27]
#     col min [11:16, 26]
#     best_point: (12,26)
# run-count 2
# Column
# col[11,16 : 27]
#   eval(11,27)
#      [0.012181908972820121, 10000000000.000599, 10000000000.0012]
#      0.0121819089728
#   eval(12,27)
#      [0.010886916232896282, 0.012415497239974815, 0.012049429392110844]
#      0.0108869162329
#   eval(13,27)
#      [0.011351350788290859, 0.01139439010688803, 0.011668275713725085]
#      0.0113513507883
#   eval(14,27)
#      [0.014347692779380861, 0.012972049123456508, 0.014085273584630409]
#      0.0129720491235
#   eval(15,27)
#      [0.020453071719868876, 0.016640277460087005, 0.020063451117476205]
#      0.0166402774601
#   Set Direction at (15,27)
#     row min [15, 23:28]
#     col min [11:16, 27]
#     best_point: (12,27)
# run-count 3
# Column
# col[11,16 : 28]
#   eval(11,28)
#      [0.014343763221156047, 10000000000.002161, 10000000000.004324]
#      0.0143437632212
#   eval(12,28)
#      [0.012277802848656871, 0.015734649836916637, 0.0149636822043413]
#      0.0122778028487
#   eval(13,28)
#      [0.011351614069539107, 0.012278066129905119, 0.010887442795392777]
#      0.0108874427954
#   eval(14,28)
#      [0.013305031561976932, 0.0112204252339132, 0.012017315665331707]
#      0.0112204252339
#   eval(15,28)
#      [0.018127507754609806, 0.012707655528436002, 0.01594650971250211]
#      0.0127076555284
#   Set Direction at (15,28)
#     row min [15, 24:29]
#     col min [11:16, 28]
#     best_point: (13,28)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 15 28
# row[16 : 24,29]
#   eval(16,24)
#      [10000000000.014702, 0.035070932306432434, 0.055236727336513081]
#      0.0350709323064
#   eval(16,25)
#      [0.044170146167068047, 0.022765311172927016, 0.038568290285485696]
#      0.0227653111729
#   eval(16,26)
#      [0.034526222237504678, 0.028545754447816041, 0.037187919441446726]
#      0.0285457544478
#   eval(16,27)
#      [0.039637705726964345, 0.02773222873923531, 0.038968745941534988]
#      0.0277322287392
#   eval(16,28)
#      [0.034679879195449126, 0.019655305984649818, 0.030535578372514638]
#      0.0196553059846
#   Set Direction at (16,28)
#     row min [16, 24:29]
#     col min [12:17, 28]
#     best_point: (13,28)
# run-count 1
# Column
# col[12,17 : 29]
#   eval(12,29)
#      [0.017213792791456739, 10000000000.004936, 0.024215743106755783]
#      0.0172137927915
#   eval(13,29)
#      [0.011941786054755377, 0.018268136050819339, 0.014386489367382072]
#      0.0119417860548
#   eval(14,29)
#      [0.011437634930760221, 0.012158995751602397, 0.011321862189086818]
#      0.0113218621891
#   eval(15,29)
#      [0.012738822919180492, 0.011353029579831309, 0.011282760015402182]
#      0.0112827600154
#   eval(16,29)
#      [0.022195829797651667, 0.013823283828404032, 0.0177887031544397]
#      0.0138232838284
#   Set Direction at (16,29)
#     row min [16, 25:30]
#     col min [12:17, 29]
#     best_point: (15,29)
# run-count 2
# Column
# col[12,17 : 30]
#   eval(12,30)
#      [0.018140111955981308, 10000000000.000927, 10000000000.001852]
#      0.018140111956
#   eval(13,30)
#      [0.011996164151893529, 0.018194490053119461, 0.017322548985733044]
#      0.0119961641519
#   eval(14,30)
#      [0.011952277276773171, 0.012626579239579883, 0.013202616230128084]
#      0.0119522772768
#   eval(15,30)
#      [0.013345978719983442, 0.014015495981354431, 0.015448299598249338]
#      0.01334597872
#   eval(16,30)
#      [0.021959451288551368, 0.021482146180130779, 0.027555094935696856]
#      0.0214821461801
#   Set Direction at (16,30)
#     row min [16, 26:31]
#     col min [12:17, 30]
#     best_point: (14,30)
# run-count 3
# Column
# col[12,17 : 31]
#   eval(12,31)
#      [0.023987604558139641, 10000000000.005848, 10000000000.011696]
#      0.0239876045581
#   eval(13,31)
#      [0.013493030560556063, 0.025484470966802175, 0.021133844773306376]
#      0.0134930305606
#   eval(14,31)
#      [0.012391524048527169, 0.013932277332310061, 0.012874657695401526]
#      0.0123915240485
#   eval(15,31)
#      [0.013346385622162615, 0.012391930950706342, 0.011953091081131517]
#      0.0119530910811
#   eval(16,31)
#      [0.023434585374340178, 0.013905530275340916, 0.01725085710840224]
#      0.0139055302753
#   Set Direction at (16,31)
#     row min [16, 27:32]
#     col min [12:17, 31]
#     best_point: (15,31)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 16 31
# row[17 : 27,32]
#   eval(17,27)
#      [10000000000.010942, 0.038674417731793809, 0.050430132432933039]
#      0.0386744177318
#   eval(17,28)
#      [0.0455035249764838, 0.026484413229339809, 0.041390443228615292]
#      0.0264844132293
#   eval(17,29)
#      [0.028953377122603263, 0.016292247721667485, 0.024593233771176726]
#      0.0162922477217
#   eval(17,30)
#      [0.024300128668841459, 0.029490027127304752, 0.029839045722751978]
#      0.0243001286688
#   eval(17,31)
#      [0.026189888698992747, 0.015795290305492204, 0.025261666240433356]
#      0.0157952903055
#   Set Direction at (17,31)
#     row min [17, 27:32]
#     col min [13:18, 31]
#     best_point: (15,31)
# run-count 1
# Column
# col[13,18 : 32]
#   eval(13,32)
#      [0.013810285341346762, 10000000000.000317, 0.024622114119721039]
#      0.0138102853413
#   eval(14,32)
#      [0.012391529964426606, 0.013810291257246199, 0.013493042392354937]
#      0.0123915299644
#   eval(15,32)
#      [0.012362889847027492, 0.012801328730322581, 0.013211121580319118]
#      0.012362889847
#   eval(16,32)
#      [0.018137385458349864, 0.01659474503003644, 0.020416801447149413]
#      0.01659474503
#   eval(17,32)
#      [0.019934677841970116, 0.020734132566514352, 0.02218430534829674]
#      0.019934677842
#   Set Direction at (17,32)
#     row min [17, 28:33]
#     col min [13:18, 32]
#     best_point: (15,32)
# run-count 2
# Column
# col[13,18 : 33]
#   eval(13,33)
#      [0.016798320286623314, 10000000000.002989, 10000000000.005976]
#      0.0167983202866
#   eval(14,33)
#      [0.013755882070627168, 0.018162672392823875, 0.016538989553747885]
#      0.0137558820706
#   eval(15,33)
#      [0.012639109668976523, 0.014032101892576199, 0.012943969608324668]
#      0.012639109669
#   eval(16,33)
#      [0.01739051412550896, 0.013434878764449043, 0.013954428037972533]
#      0.0134348787644
#   eval(17,33)
#      [0.020690605068830581, 0.014190805991309507, 0.018106599483757368]
#      0.0141908059913
#   Set Direction at (17,33)
#     row min [17, 29:34]
#     col min [13:18, 33]
#     best_point: (15,33)
# run-count 3
# Column
# col[13,18 : 34]
#   eval(13,34)
#      [0.01922208744746412, 10000000000.002424, 10000000000.004848]
#      0.0192220874475
#   eval(14,34)
#      [0.014748378386046035, 0.020214583762882987, 0.018783312917461048]
#      0.014748378386
#   eval(15,34)
#      [0.012764220736017018, 0.01487348945308653, 0.014006104204708159]
#      0.012764220736
#   eval(16,34)
#      [0.014566723413772853, 0.013896065385340828, 0.014902798967624142]
#      0.0138960653853
#   eval(17,34)
#      [0.015275040049130939, 0.014980299443162259, 0.015603346880091906]
#      0.0149802994432
#   Set Direction at (17,34)
#     row min [17, 30:35]
#     col min [13:18, 34]
#     best_point: (15,34)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 17 34
# row[18 : 30,35]
#   eval(18,30)
#      [10000000000.01697, 0.041269435697968926, 0.05023086177992242]
#      0.041269435698
#   eval(18,31)
#      [0.048381453371687422, 0.0229073079792107, 0.03852416401627845]
#      0.0229073079792
#   eval(18,32)
#      [0.033967560311923051, 0.030994930174682467, 0.037915794970916905]
#      0.0309949301747
#   eval(18,33)
#      [0.035669909384956733, 0.018865785201583773, 0.029284636262518648]
#      0.0188657852016
#   eval(18,34)
#      [0.024312486178799886, 0.020427000420378372, 0.025084207945741732]
#      0.0204270004204
#   Set Direction at (18,34)
#     row min [18, 30:35]
#     col min [14:19, 34]
#     best_point: (15,34)
# run-count 1
# Column
# col[14,19 : 35]
#   eval(14,35)
#      [0.024545337817565294, 10000000000.009796, 0.038816006310502638]
#      0.0245453378176
#   eval(15,35)
#      [0.018957723349241506, 0.030738840430789782, 0.027135383612495012]
#      0.0189577233492
#   eval(16,35)
#      [0.015045596811536943, 0.020107254775437622, 0.015063283588409249]
#      0.0150455968115
#   eval(17,35)
#      [0.016178838167597354, 0.016244135535972037, 0.016293142834211016]
#      0.0161788381676
#   eval(18,35)
#      [0.020466454200918749, 0.016218291948137731, 0.015059207004243014]
#      0.0150592070042
#   Set Direction at (18,35)
#     row min [18, 31:36]
#     col min [14:19, 35]
#     best_point: (16,35)
# run-count 2
# Column
# col[14,19 : 36]
#   eval(14,36)
#      [0.031195645428319985, 10000000000.006651, 10000000000.0133]
#      0.0311956454283
#   eval(15,36)
#      [0.022709827054097742, 0.03494774913317622, 0.032049545227277765]
#      0.0227098270541
#   eval(16,36)
#      [0.015315926998343832, 0.022980157240904631, 0.019498383722855284]
#      0.0153159269983
#   eval(17,36)
#      [0.016473202806367881, 0.01561029163711436, 0.015634326089077999]
#      0.0156102916371
#   eval(18,36)
#      [0.015623080802414702, 0.016174165435286048, 0.017306585763940729]
#      0.0156230808024
#   Set Direction at (18,36)
#     row min [18, 32:37]
#     col min [14:19, 36]
#     best_point: (18,35)
# run-count 1
# Row
#
#
# Insert: cur index 18 36
# row[19 : 32,37]
#   eval(19,32)
#      [10000000000.010986, 0.041980600470249763, 0.044878648570345292]
#      0.0419806004702
#   eval(19,33)
#      [0.046607057664556972, 0.023492242395890983, 0.040247844563296886]
#      0.0234922423959
#   eval(19,34)
#      [0.028886569405115248, 0.025821327429602636, 0.029654439220032303]
#      0.0258213274296
#   eval(19,35)
#      [0.025856433753680852, 0.015094313328321229, 0.020497213068534803]
#      0.0150943133283
#   eval(19,36)
#      [0.01564140111009038, 0.016170168584183853, 0.016153382567781316]
#      0.0156414011101
#   Set Direction at (19,36)
#     row min [19, 32:37]
#     col min [15:20, 36]
#     best_point: (19,35)
# run-count 2
# Row
#
#
# Insert: cur index 19 36
# row[20 : 32,37]
#   eval(20,32)
#      [10000000000.019377, 0.061356536725035826, 10000000000.038752]
#      0.061356536725
#   eval(20,33)
#      [0.071856416184286842, 0.033992121855141999, 0.062980359388751794]
#      0.0339921218551
#   eval(20,34)
#      [0.045632090602971687, 0.037461296177432324, 0.046772179891550358]
#      0.0374612961774
#   eval(20,35)
#      [0.039096207816683881, 0.016729224967572787, 0.029091150708105751]
#      0.0167292249676
#   eval(20,36)
#      [0.020080392633622046, 0.01899256877613964, 0.021796648660419748]
#      0.0189925687761
#   Set Direction at (20,36)
#     row min [20, 32:37]
#     col min [16:21, 36]
#     best_point: (16,36)
# run-count 1
# Column
# col[16,21 : 37]
#   eval(16,37)
#      [0.018619523295883345, 10000000000.003304, 0.029317019649176768]
#      0.0186195232959
#   eval(17,37)
#      [0.018996566607668686, 0.022005798266437671, 0.022088476939452484]
#      0.0189965666077
#   eval(18,37)
#      [0.015922477685225478, 0.019295963490479462, 0.016209085402735912]
#      0.0159224776852
#   eval(19,37)
#      [0.015953249527714264, 0.016234326102849361, 0.016246777637662468]
#      0.0159532495277
#   eval(20,37)
#      [0.019276639130519024, 0.016237319882093648, 0.016209541818849149]
#      0.0162095418188
#   Set Direction at (20,37)
#     row min [20, 33:38]
#     col min [16:21, 37]
#     best_point: (18,37)
# run-count 2
# Column
# col[16,21 : 38]
#   eval(16,38)
#      [0.018620912305642556, 10000000000.000002, 10000000000.000002]
#      0.0186209123056
#   eval(17,38)
#      [0.018996781138897023, 0.018621126836870894, 0.018619952358340019]
#      0.0186199523583
#   eval(18,38)
#      [0.017633284281694084, 0.020330758954808625, 0.022418179800605897]
#      0.0176332842817
#   eval(19,38)
#      [0.017634731736350995, 0.019314766490330815, 0.01928544210249894]
#      0.0176347317364
#   eval(20,38)
#      [0.021908313203359286, 0.023333503120861132, 0.027350792296734538]
#      0.0219083132034
#   Set Direction at (20,38)
#     row min [20, 34:39]
#     col min [16:21, 38]
#     best_point: (20,37)
# run-count 1
# Row
#
#
# Insert: cur index 20 38
# row[21 : 34,39]
#   eval(21,34)
#      [10000000000.006674, 0.044134813012334462, 0.047339155524946275]
#      0.0441348130123
#   eval(21,35)
#      [0.044335964691066154, 0.016930376646304479, 0.037863599534895709]
#      0.0169303766463
#   eval(21,36)
#      [0.017931864257837327, 0.019994056387672487, 0.018732200190638482]
#      0.0179318642578
#   eval(21,37)
#      [0.018020255534130336, 0.016297933095142159, 0.019169351328725659]
#      0.0162979330951
#   eval(21,38)
#      [0.018724443123346757, 0.024334823231563885, 0.021062561875258345]
#      0.0187244431233
#   Set Direction at (21,38)
#     row min [21, 34:39]
#     col min [17:22, 38]
#     best_point: (21,37)
# run-count 2
# Row
#
#
# Insert: cur index 21 38
# row[22 : 34,39]
#   eval(22,34)
#      [10000000000.019033, 0.063167705138447605, 10000000000.038065]
#      0.0631677051384
#   eval(22,35)
#      [0.068151513084660609, 0.021914184592517483, 0.054102428904760469]
#      0.0219141845925
#   eval(22,36)
#      [0.029664237609118072, 0.025681917274437915, 0.032430482679505657]
#      0.0256819172744
#   eval(22,37)
#      [0.027893926608039021, 0.018509942428743265, 0.022355882925039539]
#      0.0185099424287
#   eval(22,38)
#      [0.029664170234360854, 0.029878670928964346, 0.038606388706377337]
#      0.0296641702344
#   Set Direction at (22,38)
#     row min [22, 34:39]
#     col min [18:23, 38]
#     best_point: (18,38)
# run-count 1
# Column
# col[18,23 : 39]
#   eval(18,39)
#      [0.017726378017851929, 10000000000.000093, 0.01880613983065571]
#      0.0177263780179
#   eval(19,39)
#      [0.0177348251521805, 0.017826471433681434, 0.017833471113353094]
#      0.0177348251522
#   eval(20,39)
#      [0.022508979532264051, 0.018335491481085264, 0.018836064394160523]
#      0.0183354914811
#   eval(21,39)
#      [0.018727494420026303, 0.01833854277776481, 0.021914415796718378]
#      0.0183385427778
#   eval(22,39)
#      [0.03265428903383738, 0.021328661577241337, 0.02470468072229981]
#      0.0213286615772
#   Set Direction at (22,39)
#     row min [22, 35:40]
#     col min [18:23, 39]
#     best_point: (18,39)
# run-count 2
# Column
# col[18,23 : 40]
#   eval(18,40)
#      [0.019356722237876878, 10000000000.001631, 10000000000.003262]
#      0.0193567222379
#   eval(19,40)
#      [0.019394046718939184, 0.021015943804635562, 0.021044821151369297]
#      0.0193940467189
#   eval(20,40)
#      [0.018374238153778255, 0.019432793391632175, 0.017812318497566482]
#      0.0178123184976
#   eval(21,40)
#      [0.019393387005932738, 0.01886716272573441, 0.020445179937421121]
#      0.0188671627257
#   eval(22,40)
#      [0.021902745207163732, 0.019441246355656805, 0.0194867100376096]
#      0.0194412463557
#   Set Direction at (22,40)
#     row min [22, 36:41]
#     col min [18:23, 40]
#     best_point: (20,40)
# run-count 3
# Column
# col[18,23 : 41]
#   eval(18,41)
#      [0.019534283097515925, 10000000000.000177, 10000000000.000355]
#      0.0195342830975
#   eval(19,41)
#      [0.019581226028115073, 0.019721462406691814, 0.019731080856228655]
#      0.0195812260281
#   eval(20,41)
#      [0.01824629735891603, 0.020015204889464622, 0.020262004441638282]
#      0.0182462973589
#   eval(21,41)
#      [0.018896578081146753, 0.018275712714328374, 0.017871149208391168]
#      0.0178711492084
#   eval(22,41)
#      [0.022043035733532168, 0.020472938586266531, 0.024070741481485136]
#      0.0204729385863
#   Set Direction at (22,41)
#     row min [22, 37:42]
#     col min [18:23, 41]
#     best_point: (21,41)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 22 41
# row[23 : 37,42]
#   eval(23,37)
#      [10000000000.009701, 0.02820979527863321, 0.045081622974217805]
#      0.0282097952786
#   eval(23,38)
#      [0.052832164936189918, 0.054286539891917562, 0.067754681743856682]
#      0.0528321649362
#   eval(23,39)
#      [0.064094192723554877, 0.032590689364606296, 0.052188225809090771]
#      0.0325906893646
#   eval(23,40)
#      [0.03828373660323503, 0.025134293594285539, 0.032714756054498806]
#      0.0251342935943
#   eval(23,41)
#      [0.035631505963445664, 0.030970150955426656, 0.040435671093977055]
#      0.0309701509554
#   Set Direction at (23,41)
#     row min [23, 37:42]
#     col min [19:24, 41]
#     best_point: (21,41)
# run-count 1
# Column
# col[19,24 : 42]
#   eval(19,42)
#      [0.020000205532414106, 10000000000.00042, 0.020372242106113991]
#      0.0200002055324
#   eval(20,42)
#      [0.01844354648206481, 0.020197454655562885, 0.019975724274412632]
#      0.0184435464821
#   eval(21,42)
#      [0.018020272266628279, 0.01859266954030192, 0.018544543475390252]
#      0.0180202722666
#   eval(22,42)
#      [0.022428652329725907, 0.019975986010087654, 0.021782576695309919]
#      0.0199759860101
#   eval(23,42)
#      [0.040125664277766204, 0.029131499332427202, 0.038783965230945627]
#      0.0291314993324
#   Set Direction at (23,42)
#     row min [23, 38:43]
#     col min [19:24, 42]
#     best_point: (21,42)
# run-count 2
# Column
# col[19,24 : 43]
#   eval(19,43)
#      [0.021827778523107355, 10000000000.001827, 10000000000.003654]
#      0.0218277785231
#   eval(20,43)
#      [0.018511478930601122, 0.021895710971643667, 0.02013607042948673]
#      0.0185114789306
#   eval(21,43)
#      [0.019210195095225924, 0.019701401759198767, 0.0208233921392601]
#      0.0192101950952
#   eval(22,43)
#      [0.020457474671179199, 0.019691683756317468, 0.018983249588811368]
#      0.0189832495888
#   eval(23,43)
#      [0.034524583876849535, 0.024376334133233701, 0.03076215509893232]
#      0.0243763341332
#   Set Direction at (23,43)
#     row min [23, 39:44]
#     col min [19:24, 43]
#     best_point: (20,43)
# run-count 3
# Column
# col[19,24 : 44]
#   eval(19,44)
#      [0.024115987979204001, 10000000000.002289, 10000000000.004576]
#      0.0241159879792
#   eval(20,44)
#      [0.018689159458763704, 0.024293668507366584, 0.02218313957943252]
#      0.0186891594588
#   eval(21,44)
#      [0.020776869061753356, 0.020255833425291137, 0.021644826863655986]
#      0.0202558334253
#   eval(22,44)
#      [0.019267361141954487, 0.020539944978434255, 0.01977841820151216]
#      0.019267361142
#   eval(23,44)
#      [0.029048918035442184, 0.023939945044162969, 0.028328417393228333]
#      0.0239399450442
#   Set Direction at (23,44)
#     row min [23, 40:45]
#     col min [19:24, 44]
#     best_point: (20,44)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 23 44
# row[24 : 40,45]
#   eval(24,40)
#      [10000000000.007805, 0.032939844224638137, 0.048201790625311491]
#      0.0329398442246
#   eval(24,41)
#      [0.046242231076821239, 0.044272537807609758, 0.051739067298651742]
#      0.0442725378076
#   eval(24,42)
#      [0.056059796447324728, 0.040918757972142172, 0.054544668234856597]
#      0.0409187579721
#   eval(24,43)
#      [0.048372562798209451, 0.03183013895930098, 0.044039108984561759]
#      0.0318301389593
#   eval(24,44)
#      [0.038432780491119534, 0.030542586575981523, 0.037581617196870809]
#      0.030542586576
#   Set Direction at (24,44)
#     row min [24, 40:45]
#     col min [20:25, 44]
#     best_point: (20,44)
# run-count 1
# Column
# col[20,25 : 45]
#   eval(20,45)
#      [0.019113419429369394, 10000000000.000423, 0.02496450792041538]
#      0.0191134194294
#   eval(21,45)
#      [0.02245040431025247, 0.021307990314330727, 0.023078301228686371]
#      0.0213079903143
#   eval(22,45)
#      [0.01935928163765932, 0.021399910810035561, 0.020439674416700804]
#      0.0193592816377
#   eval(23,45)
#      [0.027672606251579412, 0.023091942845075764, 0.026732683556787373]
#      0.0230919428451
#   eval(24,45)
#      [0.036018466604819888, 0.028567822873914128, 0.034891705101839698]
#      0.0285678228739
#   Set Direction at (24,45)
#     row min [24, 41:46]
#     col min [20:25, 45]
#     best_point: (20,45)
# run-count 2
# Column
# col[20,25 : 46]
#   eval(20,46)
#      [0.021980752299392448, 10000000000.002867, 10000000000.005735]
#      0.0219807522994
#   eval(21,46)
#      [0.02767195104829212, 0.028344713033353841, 0.031841340897292181]
#      0.0276719510483
#   eval(22,46)
#      [0.019905594187963893, 0.028218263598596693, 0.022400615414939873]
#      0.019905594188
#   eval(23,46)
#      [0.023884403872886928, 0.020698055215775057, 0.020944203693281649]
#      0.0206980552158
#   eval(24,46)
#      [0.030254176832801516, 0.022384409174662445, 0.026464650762850539]
#      0.0223844091747
#   Set Direction at (24,46)
#     row min [24, 42:47]
#     col min [20:25, 46]
#     best_point: (22,46)
# run-count 3
# Column
# col[20,25 : 47]
#   eval(20,47)
#      [0.025267797179410523, 10000000000.003286, 10000000000.006575]
#      0.0252677971794
#   eval(21,47)
#      [0.034653606410830706, 0.032249452541949108, 0.035944063024469619]
#      0.0322494525419
#   eval(22,47)
#      [0.020643309249464337, 0.032987167603449552, 0.029147381171293008]
#      0.0206433092495
#   eval(23,47)
#      [0.021291618390127387, 0.021236872423816666, 0.021092720536668552]
#      0.0210927205367
#   eval(24,47)
#      [0.023774096364674535, 0.022482407726680642, 0.023477429595799237]
#      0.0224824077267
#   Set Direction at (24,47)
#     row min [24, 43:48]
#     col min [20:25, 47]
#     best_point: (22,47)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 24 47
# row[25 : 43,48]
#   eval(25,43)
#      [10000000000.014345, 0.046174363937070195, 0.069607207927680603]
#      0.0461743639371
#   eval(25,44)
#      [0.059329804702145994, 0.043698027341057322, 0.058141020489452577]
#      0.0436980273411
#   eval(25,45)
#      [0.055243790774243018, 0.040113586307099824, 0.053634113442352915]
#      0.0401135863071
#   eval(25,46)
#      [0.045672526444599626, 0.027943349312162247, 0.039685703148913731]
#      0.0279433493122
#   eval(25,47)
#      [0.03295246679376207, 0.027491525208280465, 0.032402644137862091]
#      0.0274915252083
#   Set Direction at (25,47)
#     row min [25, 43:48]
#     col min [21:26, 47]
#     best_point: (22,47)
# run-count 1
# Column
# col[21,26 : 48]
#   eval(21,48)
#      [0.037954911831163729, 10000000000.005705, 0.036678715757839764]
#      0.0366787157578
#   eval(22,48)
#      [0.021009168860436911, 0.037044575368812338, 0.032981171763894257]
#      0.0210091688604
#   eval(23,48)
#      [0.022142225473973487, 0.022058673797741846, 0.022742319124074206]
#      0.0220586737977
#   eval(24,48)
#      [0.024535368675789981, 0.024111634746851185, 0.025198642434887231]
#      0.0241116347469
#   eval(25,48)
#      [0.033700714042178226, 0.030320823580748946, 0.034900785394476164]
#      0.0303208235807
#   Set Direction at (25,48)
#     row min [25, 44:49]
#     col min [21:26, 48]
#     best_point: (22,48)
# run-count 2
# Column
# col[21,26 : 49]
#   eval(21,49)
#      [0.050952713500639568, 10000000000.014275, 10000000000.028547]
#      0.0509527135006
#   eval(22,49)
#      [0.024997469171482378, 0.054941013811685036, 0.044655316379930698]
#      0.0249974691715
#   eval(23,49)
#      [0.022194324779092667, 0.025133120152833199, 0.021280470823138553]
#      0.0212804708231
#   eval(24,49)
#      [0.024113251224397558, 0.021282087300684926, 0.022061906752834592]
#      0.0212820873007
#   eval(25,49)
#      [0.031531151464933238, 0.022492415184869219, 0.02653229051521977]
#      0.0224924151849
#   Set Direction at (25,49)
#     row min [25, 45:50]
#     col min [21:26, 49]
#     best_point: (23,49)
# run-count 3
# Column
# col[21,26 : 50]
#   eval(21,50)
#      [0.055243416452837479, 10000000000.004292, 10000000000.008581]
#      0.0552434164528
#   eval(22,50)
#      [0.025079996023463669, 0.05532594330481877, 0.051117767204602149]
#      0.0250799960235
#   eval(23,50)
#      [0.023081291312850749, 0.026880816513175865, 0.02859911015090677]
#      0.0230812913129
#   eval(24,50)
#      [0.024345353097339872, 0.026144557109505695, 0.027407002416448445]
#      0.0243453530973
#   eval(25,50)
#      [0.030382168042300983, 0.032235105954771637, 0.037061593015548455]
#      0.0303821680423
#   Set Direction at (25,50)
#     row min [25, 46:51]
#     col min [21:26, 50]
#     best_point: (25,49)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 25 50
# row[26 : 46,51]
#   eval(26,46)
#      [10000000000.008173, 0.036116285542344695, 0.056459458767464721]
#      0.0361162855423
#   eval(26,47)
# ...
#      0.0428956580437
#   eval(41,80)
#      [0.045250583153682356, 0.045594033434418924, 0.046424663466037575]
#      0.0452505831537
#   eval(42,80)
#      [0.044535303071879584, 0.047529093075138862, 0.047109227605848236]
#      0.0445353030719
#   eval(43,80)
#      [0.054604458378261556, 0.050381407009828183, 0.053949001026320276]
#      0.0503814070098
#   Set Direction at (43,80)
#     row min [43, 76:81]
#     col min [39:44, 80]
#     best_point: (43,78)
# run-count 1
# Row
#
#
# Insert: cur index 43 80
# row[44 : 76,81]
#   eval(44,76)
#      [10000000000.023056, 0.095503113782748228, 0.10808901459600362]
#      0.0955031137827
#   eval(44,77)
#      [0.10882293064287918, 0.063734357627403648, 0.099086412226142562]
#      0.0637343576274
#   eval(44,78)
#      [0.071056402607467484, 0.047518273295803826, 0.065058630727400368]
#      0.0475182732958
#   eval(44,79)
#      [0.065247542469004993, 0.066487623613514124, 0.075654766662142325]
#      0.065247542469
#   eval(44,80)
#      [0.078963173308142842, 0.064097037848966032, 0.076189616118588654]
#      0.064097037849
#   Set Direction at (44,80)
#     row min [44, 76:81]
#     col min [40:45, 80]
#     best_point: (40,80)
# run-count 1
# Column
# col[40,45 : 81]
#   eval(40,81)
#      [0.04290148434112373, 10000000000.000006, 0.041132122345007627]
#      0.041132122345
#   eval(41,81)
#      [0.045290520918081056, 0.041172060109406328, 0.042975533572469193]
#      0.0411720601094
#   eval(42,81)
#      [0.04453973361083674, 0.041176490648363484, 0.045259444231596668]
#      0.0411764906484
#   eval(43,81)
#      [0.051333545783776913, 0.042128629422312214, 0.046439580619777043]
#      0.0421286294223
#   eval(44,81)
#      [0.069220663203317767, 0.047252254776663949, 0.060628657718531653]
#      0.0472522547767
#   Set Direction at (44,81)
#     row min [44, 77:82]
#     col min [40:45, 81]
#     best_point: (40,81)
# run-count 2
# Column
# col[40,45 : 82]
#   eval(40,82)
#      [0.042057356768550824, 10000000000.000925, 10000000000.00185]
#      0.0420573567686
#   eval(41,82)
#      [0.042704660335162514, 0.043589956994307011, 0.04419732279652]
#      0.0427046603352
#   eval(42,82)
#      [0.042396953046341834, 0.043925122733140864, 0.043612984905363028]
#      0.0423969530463
#   eval(43,82)
#      [0.04618268300499262, 0.04645100662902224, 0.049284597813724296]
#      0.046182683005
#   eval(44,82)
#      [0.058140962058195411, 0.057071390286524082, 0.063906043985375138]
#      0.0570713902865
#   Set Direction at (44,82)
#     row min [44, 78:83]
#     col min [40:45, 82]
#     best_point: (40,82)
# run-count 3
# Column
# col[40,45 : 83]
#   eval(40,83)
#      [0.042303369407142632, 10000000000.000246, 10000000000.000492]
#      0.0423033694071
#   eval(41,83)
#      [0.043300866154380335, 0.042899575226360454, 0.043249768406986466]
#      0.0428995752264
#   eval(42,83)
#      [0.042805117621810274, 0.043307739801828893, 0.043520989486099393]
#      0.0428051176218
#   eval(43,83)
#      [0.048578619247639176, 0.04520105386445683, 0.047188825531634948]
#      0.0452010538645
#   eval(44,83)
#      [0.065108304077167722, 0.053237967655100471, 0.062256510586279901]
#      0.0532379676551
#   Set Direction at (44,83)
#     row min [44, 79:84]
#     col min [40:45, 83]
#     best_point: (40,83)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 44 83
# row[45 : 79,84]
#   eval(45,79)
#      [10000000000.016798, 0.082045803337439049, 0.081114795032671938]
#      0.0811147950327
#   eval(45,80)
#      [0.094012263242984284, 0.076994506059278378, 0.091042478889629685]
#      0.0769945060593
#   eval(45,81)
#      [0.081621941384567132, 0.051879690101952702, 0.073351908499543539]
#      0.051879690102
#   eval(45,82)
#      [0.062040280814819715, 0.067231980999391094, 0.067573436202397974]
#      0.0620402808148
#   eval(45,83)
#      [0.069452995947345886, 0.060650682787626642, 0.071896820551576424]
#      0.0606506827876
#   Set Direction at (45,83)
#     row min [45, 79:84]
#     col min [41:46, 83]
#     best_point: (42,83)
# run-count 1
# Column
# col[41,46 : 84]
#   eval(41,84)
#      [0.043078247772751932, 10000000000.000179, 0.042660714499925589]
#      0.0426607144999
#   eval(42,84)
#      [0.043114221845748202, 0.042969818723863518, 0.04351778367423631]
#      0.0429698187239
#   eval(43,84)
#      [0.045325875945603666, 0.043094640805010354, 0.043054761784103945]
#      0.0430547617841
#   eval(44,84)
#      [0.055932796200474755, 0.045749590329478229, 0.050590710955205398]
#      0.0457495903295
#   eval(45,84)
#      [0.062988926407524071, 0.048087833949375658, 0.057914454894895329]
#      0.0480878339494
#   Set Direction at (45,84)
#     row min [45, 80:85]
#     col min [41:46, 84]
#     best_point: (41,84)
# run-count 2
# Column
# col[41,46 : 85]
#   eval(41,85)
#      [0.044751470200224075, 10000000000.00209, 10000000000.004181]
#      0.0447514702002
#   eval(42,85)
#      [0.045463536494414702, 0.04724518797077526, 0.047648150041027959]
#      0.0454635364944
#   eval(43,85)
#      [0.043503880393396921, 0.045912655103707678, 0.043868055942449469]
#      0.0435038803934
#   eval(44,85)
#      [0.046132069357977756, 0.043886359421896448, 0.043819719841103]
#      0.0438197198411
#   eval(45,85)
#      [0.048343794470409374, 0.044075680362136715, 0.046261511371545661]
#      0.0440756803621
#   Set Direction at (45,85)
#     row min [45, 81:86]
#     col min [41:46, 85]
#     best_point: (43,85)
# run-count 3
# Column
# col[41,46 : 86]
#   eval(41,86)
#      [0.045719333747839208, 10000000000.000967, 10000000000.001936]
#      0.0457193337478
#   eval(42,86)
#      [0.046711329243399491, 0.046967126496823997, 0.047247055698193652]
#      0.0467113292434
#   eval(43,86)
#      [0.043547090650829179, 0.046754539500831749, 0.045549957009279218]
#      0.0435470906508
#   eval(44,86)
#      [0.044987589291693997, 0.044714960101420176, 0.045839619294578915]
#      0.0447149601014
#   eval(45,86)
#      [0.045013047539512852, 0.045652327278796312, 0.045694454195855272]
#      0.0450130475395
#   Set Direction at (45,86)
#     row min [45, 82:87]
#     col min [41:46, 86]
#     best_point: (43,86)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 45 86
# row[46 : 82,87]
#   eval(46,82)
#      [10000000000.028912, 0.090951929350372218, 0.10970298717305771]
#      0.0909519293504
#   eval(46,83)
#      [0.11510024464929469, 0.084798998086549116, 0.11033691141266466]
#      0.0847989980865
#   eval(46,84)
#      [0.098673366834562293, 0.061962202697388835, 0.088399420283652996]
#      0.0619622026974
#   eval(46,85)
#      [0.069273860145471544, 0.051387337810219424, 0.062711148845541076]
#      0.0513873378102
#   eval(46,86)
#      [0.061406625210755239, 0.055032334940048666, 0.064114255163208345]
#      0.05503233494
#   Set Direction at (46,86)
#     row min [46, 82:87]
#     col min [42:47, 86]
#     best_point: (43,86)
# run-count 1
# Column
# col[42,47 : 87]
#   eval(42,87)
#      [0.047942810067964303, 10000000000.001232, 0.048182295396968833]
#      0.047942810068
#   eval(43,87)
#      [0.043587308223209886, 0.047983027640345011, 0.046791764388160906]
#      0.0435873082232
#   eval(44,87)
#      [0.045898716258480188, 0.044771064380269898, 0.045914602964949203]
#      0.0447710643803
#   eval(45,87)
#      [0.045964653971256708, 0.045722670812013755, 0.046618172964907889]
#      0.045722670812
#   eval(46,87)
#      [0.065097947979680493, 0.055788283851645581, 0.065144273618776505]
#      0.0557882838516
#   Set Direction at (46,87)
#     row min [46, 83:88]
#     col min [42:47, 87]
#     best_point: (43,87)
# run-count 2
# Column
# col[42,47 : 88]
#   eval(42,88)
#      [0.051558996607499075, 10000000000.003616, 10000000000.007233]
#      0.0515589966075
#   eval(43,88)
#      [0.044573016022093292, 0.052544704406382481, 0.049914225665731116]
#      0.0445730160221
#   eval(44,88)
#      [0.044858529426002769, 0.044660481067826163, 0.043762238314675628]
#      0.0437622383147
#   eval(45,88)
#      [0.045756238234081148, 0.043795805736743021, 0.044838199224404685]
#      0.0437958057367
#   eval(46,88)
#      [0.061461297751314037, 0.049468819636411476, 0.057068698611350666]
#      0.0494688196364
#   Set Direction at (46,88)
#     row min [46, 84:89]
#     col min [42:47, 88]
#     best_point: (44,88)
# run-count 3
# Column
# col[42,47 : 89]
#   eval(42,89)
#      [0.057119145428474627, 10000000000.00556, 10000000000.01112]
#      0.0571191454285
#   eval(43,89)
#      [0.046674198695331515, 0.059220328101712849, 0.055761361953975519]
#      0.0466741986953
#   eval(44,89)
#      [0.043788205205245845, 0.046700165585901732, 0.044624949803233727]
#      0.0437882052052
#   eval(45,89)
#      [0.043870702918656468, 0.043863102387159292, 0.043912032678502522]
#      0.0438631023872
#   eval(46,89)
#      [0.053176181885792984, 0.047570464636540799, 0.051210530235506035]
#      0.0475704646365
#   Set Direction at (46,89)
#     row min [46, 85:90]
#     col min [42:47, 89]
#     best_point: (44,89)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 46 89
# row[47 : 85,90]
#   eval(47,85)
#      [10000000000.007746, 0.0591338012790108, 0.077455129634971587]
#      0.059133801279
#   eval(47,86)
#      [0.069660649529599938, 0.065559183190637804, 0.072441034311397701]
#      0.0655591831906
#   eval(47,87)
#      [0.076133508569441122, 0.066362609230448899, 0.076180985697655301]
#      0.0663626092304
#   eval(47,88)
#      [0.072419530412212163, 0.05552574081817474, 0.067902126215172109]
#      0.0555257408182
#   eval(47,89)
#      [0.059544816732551298, 0.051589540550917357, 0.057506971465164591]
#      0.0515895405509
#   Set Direction at (47,89)
#     row min [47, 85:90]
#     col min [43:48, 89]
#     best_point: (44,89)
# run-count 1
# Column
# col[43,48 : 90]
#   eval(43,90)
#      [0.049336347360278365, 10000000000.002663, 0.062443442758368328]
#      0.0493363473603
#   eval(44,90)
#      [0.0439060678040748, 0.04945420995910732, 0.046909923892989425]
#      0.0439060678041
#   eval(45,90)
#      [0.044070891677797985, 0.044113857094713493, 0.044203783786523232]
#      0.0440708916778
#   eval(46,90)
#      [0.050610022688127532, 0.047110449729384718, 0.049942218490332757]
#      0.0471104497294
#   eval(47,90)
#      [0.054911989147735651, 0.050432898326203013, 0.054215361830177389]
#      0.0504328983262
#   Set Direction at (47,90)
#     row min [47, 86:91]
#     col min [43:48, 90]
#     best_point: (44,90)
# run-count 2
# Column
# col[43,48 : 91]
#   eval(43,91)
#      [0.055678235177798574, 10000000000.006342, 10000000000.012684]
#      0.0556782351778
#   eval(44,91)
#      [0.04542101291800138, 0.057193180291725154, 0.052366237588131526]
#      0.045421012918
#   eval(45,91)
#      [0.045875391764927054, 0.047225513005130448, 0.047515067978332937]
#      0.0458753917649
#   eval(46,91)
#      [0.047843443462306623, 0.046608385497848959, 0.045536879143641795]
#      0.0455368791436
#   eval(47,91)
#      [0.051308102372725206, 0.046412083190163989, 0.048860857822429105]
#      0.0464120831902
#   Set Direction at (47,91)
#     row min [47, 87:92]
#     col min [43:48, 91]
#     best_point: (44,91)
# run-count 3
# Column
# col[43,48 : 92]
#   eval(43,92)
#      [0.05983133057107981, 10000000000.004152, 10000000000.008307]
#      0.0598313305711
#   eval(44,92)
#      [0.045983405637932795, 0.060393723291011225, 0.056803020617661404]
#      0.0459834056379
#   eval(45,92)
#      [0.046619198935798689, 0.04672721280880443, 0.046908627259744651]
#      0.0466191989358
#   eval(46,92)
#      [0.047324518894116707, 0.048406838686273601, 0.049450671265876878]
#      0.0473245188941
#   eval(47,92)
#      [0.048418208804857144, 0.049330644508809862, 0.049549130373028105]
#      0.0484182088049
#   Set Direction at (47,92)
#     row min [47, 88:93]
#     col min [43:48, 92]
#     best_point: (44,92)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 47 92
# row[48 : 88,93]
#   eval(48,88)
#      [10000000000.013105, 0.068631823580560636, 0.09257477475522069]
#      0.0686318235806
#   eval(48,89)
#      [0.078646902974748745, 0.061604619945105465, 0.075555899606550958]
#      0.0616046199451
#   eval(48,90)
#      [0.070502432640136892, 0.059330711021234439, 0.069385165940980209]
#      0.0593307110212
#   eval(48,91)
#      [0.063726843505361397, 0.050808215674290946, 0.059225163294456928]
#      0.0508082156743
#   eval(48,92)
#      [0.057449448713510542, 0.05505944184407674, 0.059694549268603181]
#      0.0550594418441
#   Set Direction at (48,92)
#     row min [48, 88:93]
#     col min [44:49, 92]
#     best_point: (44,92)
# run-count 1
# Column
# col[44,49 : 93]
#   eval(44,93)
#      [0.051281830014081042, 10000000000.005299, 0.070428179323376305]
#      0.0512818300141
#   eval(45,93)
#      [0.052447591921553349, 0.057110222999835702, 0.057640191609442115]
#      0.0524475919216
#   eval(46,93)
#      [0.047371027281041811, 0.052494100308478453, 0.046712215709648897]
#      0.0467122157096
#   eval(47,93)
#      [0.048436778274518311, 0.046730785179310064, 0.047361657833439041]
#      0.0467307851793
#   eval(48,93)
#      [0.056111118516459668, 0.047782461851692992, 0.050521562149623001]
#      0.0477824618517
#   Set Direction at (48,93)
#     row min [48, 89:94]
#     col min [44:49, 93]
#     best_point: (46,93)
# run-count 2
# Column
# col[44,49 : 94]
#   eval(44,94)
#      [0.055420861530513621, 10000000000.004139, 10000000000.008278]
#      0.0554208615305
#   eval(45,94)
#      [0.057056644117462585, 0.060029913726422857, 0.060499934405899514]
#      0.0570566441175
#   eval(46,94)
#      [0.046714922410422299, 0.057059350818235988, 0.052453005323100155]
#      0.0467149224104
#   eval(47,94)
#      [0.046748054976688325, 0.04673219220780056, 0.046746755304405418]
#      0.0467321922078
#   eval(48,94)
#      [0.049454588515672526, 0.048404318871780094, 0.050075038507269132]
#      0.0484043188718
#   Set Direction at (48,94)
#     row min [48, 90:95]
#     col min [44:49, 94]
#     best_point: (46,94)
# run-count 3
# Column
# col[44,49 : 95]
#   eval(44,95)
#      [0.06175476797785695, 10000000000.006334, 10000000000.012669]
#      0.0617547679779
#   eval(45,95)
#      [0.063968660135490629, 0.068666783995884995, 0.06924489356656971]
#      0.0639686601355
#   eval(46,95)
#      [0.046900562424672221, 0.064154300149740551, 0.057427924145962428]
#      0.0469005624247
#   eval(47,95)
#      [0.046855726077699833, 0.047024096294571494, 0.046961990150220845]
#      0.0468557260777
#   eval(48,95)
#      [0.049060987629117481, 0.047512394835037219, 0.048045529722475333]
#      0.047512394835
#   Set Direction at (48,95)
#     row min [48, 91:96]
#     col min [44:49, 95]
#     best_point: (47,95)
# exceeded run count
# run-count 1
# Row
#
#
# Insert: cur index 48 95
# row[49 : 91,96]
#   eval(49,91)
#      [10000000000.00639, 0.057196941345292518, 0.072108162363237582]
#      0.0571969413453
#   eval(49,92)
#      [0.066243148754781767, 0.064105649253565988, 0.068900630493269444]
#      0.0641056492536
#   eval(49,93)
#      [0.066227976655869325, 0.049904789253996329, 0.059304096648683413]
#      0.049904789254
#   eval(49,94)
#      [0.052878124147291761, 0.051377653765075526, 0.053729131638283856]
#      0.0513776537651
#   eval(49,95)
#      [0.052919501834413185, 0.049054242904374878, 0.051488015010455412]
#      0.0490542429044
#   Set Direction at (49,95)
#     row min [49, 91:96]
#     col min [45:50, 95]
#     best_point: (47,95)
# run-count 1
# Column
# col[45,50 : 96]
#   eval(45,96)
#      [0.073822946527012379, 10000000000.009853, 0.081463340760900449]
#      0.073822946527
#   eval(46,96)
#      [0.047787824584176075, 0.074710208686516233, 0.065743184454498338]
#      0.0477878245842
#   eval(47,96)
#      [0.047599758768917755, 0.048531857275393997, 0.048388627807108064]
#      0.0475997587689
#   eval(48,96)
#      [0.047601941693875438, 0.047689305627755973, 0.04703481979537627]
#      0.0470348197954
#   eval(49,96)
#      [0.049588150079768578, 0.04756872697076997, 0.048580209185824619]
#      0.0475687269708
#   Set Direction at (49,96)
#     row min [49, 92:97]
#     col min [45:50, 96]
#     best_point: (48,96)
# run-count 2
# Column
# col[45,50 : 97]
#   eval(45,97)
#      [0.078620504891744214, 10000000000.004797, 10000000000.009596]
#      0.0786205048917
#   eval(46,97)
#      [0.04778789704128128, 0.078620577348849419, 0.073823091441222788]
#      0.0477878970413
#   eval(47,97)
#      [0.047607485343008515, 0.04779562361537204, 0.047803277732357596]
#      0.047607485343
#   eval(48,97)
#      [0.048596347836623699, 0.049169013384255944, 0.050722814851412612]
#      0.0485963478366
#   eval(49,97)
#      [0.050393996537987373, 0.051421617403841102, 0.052685358929811077]
#      0.050393996538
#   Set Direction at (49,97)
#     row min [49, 93:98]
#     col min [45:50, 97]
#     best_point: (49,96)
# run-count 1
# Row

# %%
# squash out the super high values so that we can see the acc_cost matrix better.
otw_acc_cost = otw.acc_cost.copy()
otw_acc_cost[otw_acc_cost > 10**5] = 0
otw_path = np.array(otw.path)


# plt.figure(figsize=(10,20))
plt.imshow(otw_acc_cost)
plt.colorbar()
plt.plot(otw_path[:,1], otw_path[:,0], 'r')
plt.show()

# %%
ref = 'Songs/bach/bach_01.wav'
live = 'Songs/bach/bach_03.wav'
ref_seq = wav_to_chroma(ref)
live_seq = wav_to_chroma(live)

print "initializing OTW"
otw2 = OnlineTimeWarping(ref_seq, otw_params)

print "calling insert"
for i in range(live_seq.shape[1]):
    cont = otw2.insert(live_seq[:,i])
    if cont == "stop":
        break
otw2_path = otw2.path

print "testing OTW"
otw2_test = test_simple(ref, live, otw2_path)
otw2_test.get_error()
